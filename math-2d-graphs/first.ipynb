# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoint = np.array([0, 6])
ypoint = np.array([0, 250])

# %%
plt.plot(xpoint, ypoint)
plt.show()

# %%
plt.plot(xpoint, ypoint)
plt.grid()
plt.show()

# %%
plt.title("Reality")
plt.plot(xpoint, ypoint)
plt.xlabel("per semester")
plt.ylabel("my tension")
plt.show()
and
